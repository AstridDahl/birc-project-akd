# %% [markdown]
# lncRNA genes in top 50 genes for integrated and all five species

# %%
integrated_lnc = {'Undif. SG': ['LOC105376755', 'LOC442028', 'LOC107986770', 'MEF2C-AS1'],
 'Dif. SG': ['LOC105377171', 'LOC100507336', 'LOC107985508', 'LINC02645'],
 'SC.I': ['LOC105373554',
  'LINC01572',
  'MGC4859',
  'MALAT1',
  'MIR4713HG',
  'LOC100506207',
  'LOC105373592',
  'KCNQ1OT1'],
 'SC.II': ['LINC01206',
  'AP4B1-AS1',
  'ANKRD20A4-ANKRD20A20P',
  'LOC440910',
  'LINC00342',
  'LOC105376107',
  'LOC100506207',
  'ADD3-AS1',
  'LOC105379207',
  'NOVA1-DT'],
 'Early round SD': ['LOC105372004',
  'LOC101929492',
  'LINC01500',
  'LOC105377110',
  'CASC2',
  'RBAKDN'],
 'Late round SD': ['STXBP5-AS1',
  'LINC01500',
  'LINC00917',
  'LOC101929563',
  'LINC02842',
  'PCDH9-AS3',
  'LOC101929492',
  'LOC105372733',
  'LOC112268205',
  'LOC105375387',
  'LINC01492',
  'LOC105369838',
  'LINC01192',
  'LRRC7-AS1',
  'LINC00869'],
 'Elong. SD': ['LOC102723490',
  'LOC101928012',
  'SPATA42',
  'LINC00265',
  'LINC01837',
  'LOC105375477',
  'LOC100996249',
  'MAP3K14-AS1',
  'STXBP5-AS1',
  'LINC01088'],
 'Sertoli': ['MALAT1',
  'NEAT1',
  'MIR924HG',
  'LINC-PINT',
  'LOC105370504',
  'LOC112268302'],
 'Macrophage': ['MALAT1',
  'NEAT1',
  'MIR99AHG',
  'FTX',
  'LINC-PINT',
  'NR2F2-AS1',
  'MIR100HG']}

# %%
bon_lnc = {'Undif. SG': ['MEF2C-AS1',
  'SNHG15',
  'LOC107986770',
  'LOC100507412',
  'LOC105371004',
  'LOC105377171'],
 'Dif. SG': ['LOC100507336',
  'LINC02645',
  'LOC100507412',
  'ZBTB46-AS1',
  'TMX2-CTNND1'],
 'SC.I': ['MALAT1',
  'MIR4713HG',
  'LOC105373554',
  'LINC01794',
  'LINC01572',
  'LOC100507412',
  'ACTR3-AS1',
  'ZBTB46-AS1',
  'LOC105372687',
  'LOC105374308',
  'MSH5-SAPCD1'],
 'SC.II': ['LOC105379102',
  'LINC01507',
  'ANKRD20A4-ANKRD20A20P',
  'LINC02475',
  'LINC01106',
  'LOC100506207',
  'LINC01123',
  'LINC00342',
  'LINC01206',
  'STEAP2-AS1',
  'ADD3-AS1',
  'SPATA8',
  'STAG3L5P-PVRIG2P-PILRB',
  'AP4B1-AS1',
  'LOC101928030',
  'GIHCG',
  'LOC105376107'],
 'Early round SD': ['LOC105372004',
  'LOC101929894',
  'LOC105377110',
  'LOC101929492',
  'LOC112268205',
  'ZNF474-AS1',
  'LOC105370300',
  'CASC2'],
 'Late round SD': ['LOC440896',
  'LINC00917',
  'EML2-AS1',
  'STXBP5-AS1',
  'LOC101929058',
  'LOC105375971',
  'LOC105377872',
  'LOC112268205',
  'LOC101928557',
  'LINC00674',
  'LINC01492',
  'LOC105373720',
  'GABRG3-AS1',
  'PCDH9-AS3',
  'LOC105369838',
  'LOC105374016',
  'LRRC7-AS1',
  'LINC00437',
  'LINC01531'],
 'Elong. SD': ['LINC01000',
  'LINC00266-3',
  'LOC401357',
  'LOC105374341',
  'LOC440896',
  'LOC102723490',
  'LINC00674',
  'LINC01001',
  'LINC00265',
  'COLCA1',
  'LINC01837',
  'LOC101928012',
  'LOC105374577',
  'FAM157C',
  'LINC00919'],
 'Sertoli': ['MIR202HG',
  'MIR99AHG',
  'MALAT1',
  'NEAT1',
  'TTTY14',
  'LOC105373347',
  'LINC-PINT']}

# %%
chimp_lnc = {'Undif. SG': ['MEF2C-AS1',
  'LOC105377171',
  'LOC107986770',
  'LOC105376755',
  'LOC442028',
  'LINC00624'],
 'Dif. SG': ['LOC100507336',
  'LINC02645',
  'LOC101927026',
  'LOC107985508',
  'ZBTB46-AS1',
  'LOC105377171',
  'MEF2C-AS1',
  'LINC00333',
  'SPANXA2-OT1'],
 'SC.I': ['LOC105373554',
  'LOC105376107',
  'LOC100506207',
  'LOC105373786',
  'LINC02478',
  'MGC4859',
  'LINC00466',
  'CLCA4-AS1',
  'LOC105377632'],
 'SC.II': ['MIR548A1HG',
  'LINC01818',
  'ANKRD20A4-ANKRD20A20P',
  'LINC01206',
  'DLEU1',
  'SCHLAP1',
  'AP4B1-AS1',
  'ADD3-AS1',
  'LOC100506207',
  'LOC440910',
  'LOC105379207',
  'LOC112268136',
  'SNHG31'],
 'Early round SD': ['LOC105372004',
  'LOC101929492',
  'LINC01500',
  'LOC101928236',
  'LOC105372733',
  'STXBP5-AS1',
  'LOC105375551',
  'LOC107984035',
  'LINC01609',
  'LOC105374007',
  'LOC105377110'],
 'Late round SD': ['STXBP5-AS1',
  'LOC105369838',
  'LOC105372733',
  'LOC107984035',
  'LOC101929563',
  'LINC01492',
  'GABRG3-AS1',
  'LOC440896',
  'LOC101929058',
  'LRRC7-AS1',
  'LOC105374455'],
 'Elong. SD': ['LOC101928012',
  'LINC01492',
  'LOC102723490',
  'STXBP5-AS1',
  'LINC01088',
  'LINC02465'],
 'Sertoli': ['NEAT1',
  'MALAT1',
  'MIR99AHG',
  'SLC7A14-AS1',
  'LOC105373347',
  'LOC105375523',
  'MIR924HG',
  'LOC105370504'],
 'Macrophage': ['MALAT1',
  'MIR99AHG',
  'NEAT1',
  'FTX',
  'LINC-PINT',
  'NR2F2-AS1',
  'MIR100HG',
  'ADAMTS9-AS2',
  'LOC107984001',
  'LOC105372676']}

# %%
gor_lnc = {'Undif. SG': ['LOC107984294',
  'LINC02096',
  'LOC105376755',
  'LINC01193',
  'LOC442028',
  'LOC107985675',
  'LINC02089'],
 'Dif. SG': ['LOC105369896',
  'LOC107986487',
  'LOC339975',
  'LOC105376131',
  'LOC105372004',
  'MALAT1',
  'LOC105374655',
  'LOC107986770',
  'LOC101927026',
  'LINC01193',
  'LOC100507336',
  'LOC101927437',
  'LOC100996294',
  'OFCC1',
  'LOC107985037',
  'LINC01194'],
 'SC.I': ['LOC105373554',
  'LINC01572',
  'LINC01794',
  'MGC4859',
  'LOC100507384',
  'LOC105378128',
  'KCNQ1OT1',
  'LOC649133',
  'SLMO2-ATP5E'],
 'SC.II': ['GIHCG',
  'LINC01507',
  'AP4B1-AS1',
  'SPATA8',
  'LINC01206',
  'LOC349160',
  'LOC728715'],
 'Early round SD': ['RBAKDN',
  'LOC105372835',
  'CT75',
  'KCNK4-TEX40',
  'HDAC4-AS1',
  'LOC101926934',
  'LINC01970',
  'DNAJC27-AS1',
  'LOC100652758',
  'LOC107984000',
  'VPS13A-AS1'],
 'Late round SD': ['RBAKDN',
  'LOC105375461',
  'LOC105370167',
  'LOC102723968',
  'LINC01492',
  'LOC107985239',
  'LINC00437',
  'LOC102723684',
  'LINC00379',
  'LOC105373593',
  'LOC105371309',
  'LOC102725019',
  'LINC01911',
  'LINC01000',
  'LINC02842'],
 'Elong. SD': ['LINC01000',
  'LOC401357',
  'LINC00999',
  'SPATA42',
  'LINC00265',
  'MIR193BHG',
  'LINC01061',
  'ILRUN-AS1',
  'LOC101929998',
  'LARGE-AS1',
  'USP2-AS1'],
 'Sertoli': ['MIR202HG', 'MIR924HG'],
 'Macrophage': ['MALAT1', 'MIR99AHG', 'NEAT1', 'NR2F2-AS1', 'FTX', 'MEG3']}

# %%
mac_lnc = {'Undif. SG': ['MALAT1',
  'NR2F2-AS1',
  'MIR99AHG',
  'LINC-PINT',
  'NEAT1',
  'MIR100HG',
  'LOC107986022',
  'LINC02456'],
 'Dif. SG': ['KCNQ1OT1',
  'LOC101928697',
  'LOC105372666',
  'FOXD3-AS1',
  'LOC101927026'],
 'SC.I': ['TEX41',
  'LINC02367',
  'LOC105373554',
  'LOC100507384',
  'RALGPS2-AS1',
  'LINC01483',
  'TDRG1',
  'CLCA4-AS1',
  'GTSCR1',
  'GIHCG',
  'LINC02583',
  'LOC107986766',
  'LOC101927284',
  'MGC4859',
  'AP4B1-AS1'],
 'SC.II': ['LOC101927284',
  'LINC00993',
  'ZNF385D-AS2',
  'LOC105370982',
  'LOC105379271',
  'LOC101928278',
  'LOC105376107',
  'LOC440910',
  'LOC107986487',
  'LINC02337',
  'AP4B1-AS1',
  'RALGPS2-AS1',
  'LOC105377604',
  'LOC105379164'],
 'Early round SD': ['LOC105379110',
  'LOC105378685',
  'LINC00345',
  'LINC01470',
  'LOC105377110',
  'LOC105373790',
  'LOC105378415',
  'GACAT3',
  'LOC101929298',
  'CDIPTOSP',
  'LINC01743',
  'LINC01500'],
 'Late round SD': ['LOC107986400',
  'STXBP5-AS1',
  'LOC105374894',
  'LINC02507',
  'LOC107984555',
  'LOC105377999',
  'LOC101929140',
  'LOC107984782',
  'SHROOM3-AS1',
  'LINC00674',
  'LINC01088',
  'LINC02741',
  'GABRG3-AS1'],
 'Elong. SD': ['LOC100502572',
  'LOC101928012',
  'LOC107984361',
  'LOC107984615',
  'LINC00442',
  'FLJ46875',
  'LOC101927151',
  'LINC00674',
  'LOC105370582',
  'C5orf60',
  'LINC01317'],
 'Sertoli': ['LOC101929200', 'MIR202HG']}

# %%
hum_lnc = {'Undif. SG': ['LOC105376755', 'LOC105374557', 'LOC442028', 'LINC01193'],
 'Dif. SG': ['LOC105377171', 'LOC107986770', 'LOC101928688'],
 'SC.I': ['LOC100506207',
  'LINC01572',
  'TEX41',
  'LOC105373592',
  'LOC105373554',
  'LINC00466'],
 'SC.II': ['ANKRD20A4-ANKRD20A20P',
  'LINC01206',
  'ADD3-AS1',
  'AP4B1-AS1',
  'LOC105379207',
  'LOC105369228',
  'LOC102724151',
  'F11-AS1',
  'LOC440910',
  'LOC646762',
  'LINC00342'],
 'Early round SD': ['RBAKDN',
  'LINC01500',
  'ZNF133-AS1',
  'GRM7-AS3',
  'LINC01609',
  'LOC101928236',
  'PCDH9-AS3',
  'LOC101929492',
  'LINC02235',
  'LINC01911',
  'LOC112268205'],
 'Late round SD': ['LINC00917',
  'LINC01492',
  'STXBP5-AS1',
  'LINC02842',
  'LOC105375387',
  'LINC01988',
  'ILRUN-AS1',
  'CRPPA-AS1',
  'LOC100134040',
  'LOC101929998',
  'LINC01500',
  'LOC105377955',
  'LOC105373593',
  'LOC105375409'],
 'Elong. SD': ['LOC100996249',
  'LINC00265',
  'LOC102723490',
  'LOC101928278',
  'LOC105376108',
  'SPATA42',
  'LOC105375477',
  'MAP3K14-AS1',
  'LINC02491',
  'COLCA1',
  'LINC01837',
  'LINC01000'],
 'Sertoli': ['NEAT1',
  'MIR924HG',
  'LOC105370504',
  'MALAT1',
  'DANT2',
  'LOC112268302',
  'LINC-PINT'],
 'Macrophage': ['MALAT1',
  'NEAT1',
  'FTX',
  'LINC-PINT',
  'LINC02388',
  'MEG8',
  'MIR99AHG']}

# %%
integrated_lnc
# Out:
# {'Undif. SG': ['LOC105376755', 'LOC442028', 'LOC107986770', 'MEF2C-AS1'],
#  'Dif. SG': ['LOC105377171', 'LOC100507336', 'LOC107985508', 'LINC02645'],
#  'SC.I': ['LOC105373554',
#   'LINC01572',
#   'MGC4859',
#   'MALAT1',
#   'MIR4713HG',
#   'LOC100506207',
#   'LOC105373592',
#   'KCNQ1OT1'],
#  'SC.II': ['LINC01206',
#   'AP4B1-AS1',
#   'ANKRD20A4-ANKRD20A20P',
#   'LOC440910',
#   'LINC00342',
#   'LOC105376107',
#   'LOC100506207',
#   'ADD3-AS1',
#   'LOC105379207',
#   'NOVA1-DT'],
#  'Early round SD': ['LOC105372004',
#   'LOC101929492',
#   'LINC01500',
#   'LOC105377110',
#   'CASC2',
#   'RBAKDN'],
#  'Late round SD': ['STXBP5-AS1',
#   'LINC01500',
#   'LINC00917',
#   'LOC101929563',
#   'LINC02842',
#   'PCDH9-AS3',
#   'LOC101929492',
#   'LOC105372733',
#   'LOC112268205',
#   'LOC105375387',
#   'LINC01492',
#   'LOC105369838',
#   'LINC01192',
#   'LRRC7-AS1',
#   'LINC00869'],
#  'Elong. SD': ['LOC102723490',
#   'LOC101928012',
#   'SPATA42',
#   'LINC00265',
# ...

# %%
bon_hum = {'Undif. SG':[],'Dif. SG':[],'SC.I':[],'SC.II':[],'Early round SD':[],'Late round SD':[],'Elong. SD':[],'Sertoli':[]}
count = 0

for celltype, genes in bon_lnc.items():
    for gene in genes:
        if gene in hum_lnc[celltype]:
            count += 1
            bon_hum[celltype].append(gene)
            
print(count/75)         
bon_hum
# Out:
# 0.26666666666666666
# {'Undif. SG': [],
#  'Dif. SG': [],
#  'SC.I': ['LOC105373554', 'LINC01572'],
#  'SC.II': ['ANKRD20A4-ANKRD20A20P',
#   'LINC00342',
#   'LINC01206',
#   'ADD3-AS1',
#   'AP4B1-AS1'],
#  'Early round SD': ['LOC101929492', 'LOC112268205'],
#  'Late round SD': ['LINC00917', 'STXBP5-AS1', 'LINC01492'],
#  'Elong. SD': ['LINC01000',
#   'LOC102723490',
#   'LINC00265',
#   'COLCA1',
#   'LINC01837'],
#  'Sertoli': ['MALAT1', 'NEAT1', 'LINC-PINT']}

# %%
# hvilke af top50 lncRNAs i chimp der optræder i tilsvarende celletype i hum top50
chimp_hum = {'Undif. SG':[],'Dif. SG':[],'SC.I':[],'SC.II':[],'Early round SD':[],'Late round SD':[],'Elong. SD':[],'Sertoli':[],'Macrophage':[]}
count = 0

for celltype, genes in chimp_lnc.items():
    for gene in genes:
        if gene in hum_lnc[celltype]:
            count += 1
            chimp_hum[celltype].append(gene)
            
print(count/75) # out of hum lnc genes
print(count/88) # out of own lnc genes (better considering only some species have macrophages)
chimp_hum
# Out:
# 0.37333333333333335
# 0.3181818181818182
# {'Undif. SG': ['LOC105376755', 'LOC442028'],
#  'Dif. SG': ['LOC105377171'],
#  'SC.I': ['LOC105373554', 'LOC100506207', 'LINC00466'],
#  'SC.II': ['ANKRD20A4-ANKRD20A20P',
#   'LINC01206',
#   'AP4B1-AS1',
#   'ADD3-AS1',
#   'LOC440910',
#   'LOC105379207'],
#  'Early round SD': ['LOC101929492', 'LINC01500', 'LOC101928236', 'LINC01609'],
#  'Late round SD': ['STXBP5-AS1', 'LINC01492'],
#  'Elong. SD': ['LOC102723490'],
#  'Sertoli': ['NEAT1', 'MALAT1', 'MIR924HG', 'LOC105370504'],
#  'Macrophage': ['MALAT1', 'MIR99AHG', 'NEAT1', 'FTX', 'LINC-PINT']}

# %%
gor_hum = {'Undif. SG':[],'Dif. SG':[],'SC.I':[],'SC.II':[],'Early round SD':[],'Late round SD':[],'Elong. SD':[],'Sertoli':[],'Macrophage':[]}
count = 0

for celltype, genes in gor_lnc.items():
    for gene in genes:
        if gene in hum_lnc[celltype]:
            count += 1
            gor_hum[celltype].append(gene)
            
print(count/75)         
gor_hum
# Out:
# 0.26666666666666666
# {'Undif. SG': ['LOC105376755', 'LINC01193', 'LOC442028'],
#  'Dif. SG': ['LOC107986770'],
#  'SC.I': ['LOC105373554', 'LINC01572'],
#  'SC.II': ['AP4B1-AS1', 'LINC01206'],
#  'Early round SD': ['RBAKDN'],
#  'Late round SD': ['LINC01492', 'LOC105373593', 'LINC02842'],
#  'Elong. SD': ['LINC01000', 'SPATA42', 'LINC00265'],
#  'Sertoli': ['MIR924HG'],
#  'Macrophage': ['MALAT1', 'MIR99AHG', 'NEAT1', 'FTX']}

# %%
# hvilke af top50 lncRNAs i chimp der optræder i tilsvarende celletype i hum top50
mac_hum = {'Undif. SG':[],'Dif. SG':[],'SC.I':[],'SC.II':[],'Early round SD':[],'Late round SD':[],'Elong. SD':[],'Sertoli':[],'Macrophage':[]}
count = 0

for celltype, genes in mac_lnc.items():
    for gene in genes:
        if gene in hum_lnc[celltype]:
            count += 1
            mac_hum[celltype].append(gene)
            
print(count/75)         
chimp_hum
# Out:
# 0.08
# {'Undif. SG': ['LOC105376755', 'LOC442028'],
#  'Dif. SG': ['LOC105377171'],
#  'SC.I': ['LOC105373554', 'LOC100506207', 'LINC00466'],
#  'SC.II': ['ANKRD20A4-ANKRD20A20P',
#   'LINC01206',
#   'AP4B1-AS1',
#   'ADD3-AS1',
#   'LOC440910',
#   'LOC105379207'],
#  'Early round SD': ['LOC101929492', 'LINC01500', 'LOC101928236', 'LINC01609'],
#  'Late round SD': ['STXBP5-AS1', 'LINC01492'],
#  'Elong. SD': ['LOC102723490'],
#  'Sertoli': ['NEAT1', 'MALAT1', 'MIR924HG', 'LOC105370504'],
#  'Macrophage': ['MALAT1', 'MIR99AHG', 'NEAT1', 'FTX', 'LINC-PINT']}
